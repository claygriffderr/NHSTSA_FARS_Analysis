# %% [markdown]
# This notebook will be largely for a statistical approach to exploring the data generated in DataImport

# %%
import pandas as pd
import scipy
import seaborn as sns
import matplotlib as plt
import sklearn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 5
#       3 import seaborn as sns
#       4 import matplotlib as plt
# ----> 5 import sklearn
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
filename = r"C:\Users\Clayg\OneDrive\Desktop\College\Fall 25 classes\Machine Learning\CS-3120-Project\GeneratedData\GeneratedMotorcycleData"

# %%
df = pd.read_csv(filename)

# %%
df.head()
# Out:
#    ST_CASE  VEH_NO  OWNER  J_KNIFE  TRAV_SP  DR_DRINK  L_STATUS  PREV_SPD  \
# 0    10087       1      2        0       60         1         1         2
# 1    10114       1      1        0        0         0         1         0
# 2    10114       1      1        0        0         0         1         0
# 3    10201       2      2        0       75         0         1         1
# 4    10201       2      2        0       75         0         1         1
#
#    PREV_OTH  SPEEDREL  ...  FUNC_SYS  HARM_EV  MAN_COLL  RELJCT2  TYP_INT  \
# 0         1       1.0  ...         3      1.0         9        1        1
# 1         0       1.0  ...         3      4.0         8        1        1
# 2         0       1.0  ...         3      4.0         8        1        1
# 3         0       1.0  ...         3      4.0         6        2        3
# 4         0       1.0  ...         3      4.0         6        2        3
#
#    REL_ROAD  WEATHER  VEH_AGE  OTHER_VEH_SP  OTHER_VEH_AVG_WEIGHT
# ...

# %%
print(df.shape)
# Out:
# (20341, 25)

# %%
col_names = df.columns.tolist()
print(col_names)
# Out:
# ['ST_CASE', 'VEH_NO', 'OWNER', 'J_KNIFE', 'TRAV_SP', 'DR_DRINK', 'L_STATUS', 'PREV_SPD', 'PREV_OTH', 'SPEEDREL', 'VE_TOTAL', 'VE_FORMS', 'HOUR', 'LGT_COND', 'RUR_URB', 'FUNC_SYS', 'HARM_EV', 'MAN_COLL', 'RELJCT2', 'TYP_INT', 'REL_ROAD', 'WEATHER', 'VEH_AGE', 'OTHER_VEH_SP', 'OTHER_VEH_AVG_WEIGHT']

# %% [markdown]
# Create column categories for statistical testing

# %%
ordinal = ['TRAV_SP', 'PREV_SPD', 'PREV_OTH', 'VE_TOTAL', 'VE_FORMS', 'HOUR', 'VEH_AGE', 'OTHER_VEH_SP', 'OTHER_VEH_AVG_WEIGHT']
nominal = ['OWNER', 'J_KNIFE', 'DR_DRINK', 'L_STATUS', 'SPEEDREL', 'LGT_COND', 'RUR_URB', 'FUNC_SYS', 'HARM_EV', 'MAN_COLL', 'RELJCT2', 'TYP_INT', 'REL_ROAD', 'WEATHER']

# %%
for col in ordinal:
    unique_vals = df[col].unique().tolist()
    print(f"Column {col} has unique vals: {unique_vals}")
# Out:
# Column TRAV_SP has unique vals: [60, 0, 75, 55, 40, 30, 70, 25, 85, 120, 35, 45, 20, 90, 65, 10, 50, 98, 15, 100, 80, 95, 49, 59, 89, 93, 42, 24, 37, 32, 5, 84, 44, 52, 47, 61, 68, 125, 76, 51, 36, 74, 46, 77, 48, 81, 64, 124, 43, 140, 53, 73, 79, 58, 62, 38, 63, 28, 18, 33, 110, 71, 1, 78, 106, 67, 96, 130, 137, 119, 102, 72, 8, 105, 57, 12, 3, 87, 31, 92, 41, 29, 56, 23, 88, 34, 112, 104, 94, 118, 115, 99, 69, 66, 22, 2, 113, 150, 86, 128, 82, 83, 54, 141, 107, 19, 4, 13, 122, 14, 127, 39, 26, 27, 97, 9, 91, 103, 16, 147, 108, 136, 134, 117, 139, 21]
# Column PREV_SPD has unique vals: [2, 0, 1, 3, 4, 5, 6, 9, 7, 8]
# Column PREV_OTH has unique vals: [1, 0, 2, 6, 4, 3, 7, 5, 9, 35, 12, 19, 10, 11, 15, 8, 21, 14, 16, 13]
# Column VE_TOTAL has unique vals: [1, 2, 5, 3, 4, 8, 6, 7, 11]
# Column VE_FORMS has unique vals: [1, 2, 5, 3, 4, 8, 7, 6, 11]
# Column HOUR has unique vals: [24, 12, 19, 21, 15, 16, 20, 13, 11, 17, 14, 9, 2, 23, 7, 10, 18, 4, 8, 22, 6, 5, 3, 0, 1]
# ...

# %% [markdown]
# ## NM
